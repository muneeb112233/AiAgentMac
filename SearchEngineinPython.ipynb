# %%
# %pip install google-search-results
# Out:
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from google-search-results) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests->google-search-results) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests->google-search-results) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests->google-search-results) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (from requests->google-search-results) (2026.6.17)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (pyproject.toml) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32092 sha256=d2d79aa03c116d564cdeeb2ebcfeacea7c2691d1c5a0e8fa06d2bc8acd1d3f82
#   Stored in directory: /Users/macbookair/Library/Caches/pip/wheels/ec/68/6c/3fc2479ee7b507f81bbfd03a99f0c1e28834cb5a5af8e8ac3f
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
serp_api_key= os.getenv("SERP_API_KEY")
# Out:
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from serpapi import GoogleSearch

def serpapi_search(query: str):
    params = {
        "q": query,
        "hl": "en",
        "gl": "us",
        "api_key": serp_api_key
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    
    # Extract top results (titles + links)
    if "organic_results" in results:
        return [
            {"title": r["title"], "link": r["link"], "snippet": r.get("snippet", "")}
            for r in results["organic_results"][:5]
        ]
    return {"error": "No results found"}

# %%
serpapi_search("Ronaldo is True Goat not Teddy Goat")
# Out:
# [{'title': 'Between Lionel Messi and Cristiano Ronaldo, who is the ...',
#   'link': 'https://www.facebook.com/WeruTV/posts/between-lionel-messi-and-cristiano-ronaldo-who-is-the-real-goat-drop-your-choice/1562429605903137/',
#   'snippet': 'Between Lionel Messi and Cristiano Ronaldo, who is the real "GOAT"?😅😅 Drop your choice in the comments and tell us why ? #werudigital'},
#  {'title': 'Who is the real GOAT 🐐 … Ronaldo or Messi . . . . . . . . . . ...',
#   'link': 'https://www.facebook.com/iamsalmanzofficial/posts/who-is-the-real-goat-ronaldo-or-messiiamsalmanz-reels-explorepage-foryou-pakista/1670642571731598/',
#   'snippet': "Ronaldo is not the Goat but ・ keep fighting over who is the real goat its the Ronaldo ・ you say Teddy Goat, Messi, Ronaldo, that's a hatted ..."},
#  {'title': 'Cristiano Ronaldo: The Most H@ted GOAT in Sports History?',
#   'link': 'https://www.youtube.com/watch?v=UBdM9Dwe_2g',
#   'snippet': 'Cristiano Ronaldo is one of the greatest athletes in history, yet he receives more criticism than almost any footballer ever. Why?'},
#  {'title': 'Do you think Messi or Cristiano Ronaldo is the GOAT?',
#   'link': 'https://www.zhihu.com/en/answer/38136634315',
#   'snippet': 'Cristiano Ronaldo\'s problem is not "whether he is the GOAT," but "whether he can make it into the top ten in history."Cristiano Ronaldo\'s problem is not ...'},
#  {'title': 'Who is the real GOAT … Ronaldo or Messi ...',
#   'link': 'https://www.instagram.com/reel/Da-u1R9M4Zg/',
#   'snippet': "It's either Ronaldo or Messi. teddy goats. Ronaldo Could Not, Citing It as the Reason They Consider Him the GOAT. is the GOAT, Not Ronaldo."}]

# %%
from langchain.agents import create_agent
from pydantic import SecretStr
from langgraph.checkpoint.memory import InMemorySaver
from dotenv import load_dotenv
import os
load_dotenv()
groq_api_key=os.getenv("GROQ_API_KEY")
serp_api_key=os.getenv("SERP_API_KEY")
from langchain_groq import ChatGroq
from serpapi import GoogleSearch

llm = ChatGroq(
    model="openai/gpt-oss-120b",
    temperature=0.1,
    max_retries=2,
    api_key=SecretStr(groq_api_key) if groq_api_key is not None else None
)
def serpapi_search(query: str):
    """Searches for a query using the SerpAPI on Google."""
    params = {
        "q": query,
        "hl": "en",
        "gl": "us",
        "api_key": SecretStr(serp_api_key) if serp_api_key is not None else None
    }
    search = GoogleSearch(params)
    results = search.get_dict()
    
    # Extract top results (titles + links)
    if "organic_results" in results:
        return [
            {"title": r["title"], "link": r["link"], "snippet": r.get("snippet", "")}
            for r in results["organic_results"][:5]
        ]
    return {"error": "No results found"}
memory= InMemorySaver()
agent= create_agent(
    model=llm,
    tools=[serpapi_search],
    system_prompt="You are a Helpful Coding Agent Only Answer Questions Related to Programming and Computers. Basically IT related.",
    checkpointer=memory
)

# %%
# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "Define comments and type Hints? Also state 3 differences and comparison points in precise and Concise manner."}]},
    config={"configurable": {"thread_id": "user123"}}
)

# Last Message
print(response['messages'][-1].content)
# Out:
# **Comments**
# - Plain‑text annotations placed in source code.
# - Ignored by the interpreter/compiler at runtime.
# - Used to explain *why* code does something, document intent, or temporarily disable code.
#
# **Type Hints (Type Annotations)**
# - Optional syntactic markers that describe the expected data types of variables, function parameters, and return values (e.g., `def add(a: int, b: int) -> int:`).
# - Retained in the compiled bytecode but have no effect on execution unless a static‑type checker (mypy, pyright, etc.) or runtime validator is used.
# - Serve as machine‑readable documentation that aids IDEs, linters, and tooling.
#
# ---
#
# ### 3 Key Differences / Comparison Points
#
# | Aspect | Comments | Type Hints |
# |--------|----------|------------|
# | **Effect on Execution** | Completely ignored; no runtime impact. | Ignored by the interpreter but can be processed by external tools; optional runtime checks can be added. |
# | **Purpose** | Human‑readable explanation, code clarification, or temporary code removal. | Machine‑readable specification of expected types to improve static analysis, autocomplete, and documentation. |
# | **Tooling Support** | Limited to IDE syntax highlighting and documentation generators. | Strong support: static type checkers, IDE type inference, refactoring tools, and documentation generators (e.g., Sphinx autodoc). |
#
# In short, comments are *purely for developers*, while type hints are *both for developers and tooling* to convey type information.

# %%
# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "What were we Talking About Earlier ?"}]},
    config={"configurable": {"thread_id": "user123"}}
)

# Last Message
print(response['messages'][-1].content)
# Out:
# We were discussing **comments** and **type hints** in programming:
#
# * **Comments** – plain‑text notes in code that the interpreter/compiler ignores; they explain *why* something is done or temporarily disable code.
# * **Type hints** – optional annotations that specify expected data types for variables, parameters, and return values (e.g., `def foo(x: int) -> str:`). They don’t affect execution by themselves but are used by static type checkers, IDEs, and documentation tools.
#
# I also highlighted three concise comparison points—execution effect, purpose, and tooling support—showing how comments are purely for human readers while type hints serve both humans and tooling.

# %%
# Run the agent
response=agent.invoke(
    {"messages": [{"role": "user", "content": "how long did AI Engineering get to Loop Engineering "}]},
    config={"configurable": {"thread_id": "user123"}}
)

# Last Message
print(response['messages'][-1].content)
# Out:
# I’m not sure I understand the question. Could you clarify what you mean by “how long did AI Engineering get to Loop Engineering”? Are you asking about a timeline for a specific project, a transition between two engineering disciplines, or something else? Providing a bit more context will help me give you an accurate answer.
