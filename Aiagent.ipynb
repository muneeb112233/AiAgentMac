# %%
# %pip install -U langchain langgraph
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-groq
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.6/561.6 kB 1.0 MB/s  0:00:00 eta 0:00:01
# ...
#   Attempting uninstall: langchain-core━━━━━━━━━━ 0/3 [filetype]
#     Found existing installation: langchain-core 1.4.9m0/3 [filetype]
#     Uninstalling langchain-core-1.4.9:0m━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [langchain-core]
#       Successfully uninstalled langchain-core-1.4.9━━━━━━━━━━━ 1/3 [langchain-core]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [langchain-google-genai]hain-google-genai]
# ...
# Note: you may need to restart the kernel to use updated packages.
